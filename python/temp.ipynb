# %%
# %pip show numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\__main__.py", line 22, in <module>
#     from pip._internal.cli.main import main as _main
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\cli\main.py", line 10, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\cli\autocompletion.py", line 9, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\cli\main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\build_env.py", line 15, in <module>
#     from pip._vendor.packaging.requirements import Requirement
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\requirements.py", line 23, in <module>
#     from .markers import MARKER_EXPR, Marker
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\markers.py", line 23, in <module>
#     from .specifiers import InvalidSpecifier, Specifier
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\specifiers.py", line 24, in <module>
#     from .utils import canonicalize_version
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\utils.py", line 11, in <module>
#     from .tags import Tag, parse_tag
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\tags.py", line 23, in <module>
#     from . import _manylinux, _musllinux
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\_manylinux.py", line 12, in <module>
#     from ._elffile import EIClass, EIData, ELFFile, EMachine
# ModuleNotFoundError: No module named 'pip._vendor.packaging._elffile'

# %%
# %pip install numpy==1.24.4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\__main__.py", line 22, in <module>
#     from pip._internal.cli.main import main as _main
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\cli\main.py", line 10, in <module>
#     from pip._internal.cli.autocompletion import autocomplete
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\cli\autocompletion.py", line 9, in <module>
#     from pip._internal.cli.main_parser import create_main_parser
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\cli\main_parser.py", line 9, in <module>
#     from pip._internal.build_env import get_runnable_pip
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_internal\build_env.py", line 15, in <module>
#     from pip._vendor.packaging.requirements import Requirement
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\requirements.py", line 23, in <module>
#     from .markers import MARKER_EXPR, Marker
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\markers.py", line 23, in <module>
#     from .specifiers import InvalidSpecifier, Specifier
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\specifiers.py", line 24, in <module>
#     from .utils import canonicalize_version
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\utils.py", line 11, in <module>
#     from .tags import Tag, parse_tag
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\tags.py", line 23, in <module>
#     from . import _manylinux, _musllinux
#   File "c:\Users\jrp\OneDrive\Dokuments\My Documents\School\MFF\Mathematics\Finanční Matematika\thesis\source\python\.venv\Lib\site-packages\pip\_vendor\packaging\_manylinux.py", line 12, in <module>
#     from ._elffile import EIClass, EIData, ELFFile, EMachine
# ModuleNotFoundError: No module named 'pip._vendor.packaging._elffile'

# %%
# %pip uninstall numpy --yes
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping numpy as it is not installed.

# %%
import pandas as pd

data = pd.read_csv('data/combined_data.csv',parse_dates=['start_date'])
